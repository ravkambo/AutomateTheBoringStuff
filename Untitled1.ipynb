# %% [markdown]
# <a href="https://colab.research.google.com/github/ravkambo/AutomateTheBoringStuff/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
testString = 'What is happening'
test = testString.split()
print(test)
# Out:
# hello world
# ['What', 'is', 'happening']
