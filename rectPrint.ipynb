# %% [markdown]
# <a href="https://colab.research.google.com/github/ravkambo/AutomateTheBoringStuff/blob/main/rectPrint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Automate the boring stuff - workbook. Chapter 1

print('Please input width')
width = int(input())
print('0' * width)
print('0' * width)
print('0' * width)
print('0' * width)
print('0' * width)
# Out:
# Please input width
# 15
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
